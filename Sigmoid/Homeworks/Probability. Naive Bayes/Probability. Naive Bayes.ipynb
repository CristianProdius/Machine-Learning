# %% [markdown]
# # Probability. Naive Bayes

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNBdf

# %%
df =pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  7590-VHVEG  Female              0     Yes         No       1           No  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection
# 0  No phone service             DSL             No  ...               No  \
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoders = {}

for column in df.columns:
    label_encoder = LabelEncoder()
    df[column] = label_encoder.fit_transform(df[column])
    label_encoders[column] = label_encoder

df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure
# 0        5375       0              0        1           0       1  \
# 1        3962       1              0        0           0      34
# 2        2564       1              0        0           0       2
# 3        5535       1              0        0           0      45
# 4        6511       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...
# 0             0              1                0               0  ...  \
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract
# 0                 0            0            0                0         0  \
# ...

# %%
X = df.drop(['Churn'], axis = 1)
y = df['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.3)

# %% [markdown]
# ## Gausian Naive Bayes

# %%
Gauss = GaussianNB()
Gauss.fit(X_train, y_train)
Gauss.score(X_test, y_test)
# Out:
# 0.7586370089919545

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
Multinomial = MultinomialNB()
Multinomial.fit(X_train, y_train)
Multinomial.score(X_test, y_test)
# Out:
# 0.6100331282536677

# %% [markdown]
# ## Bernouli Naive Bayes

# %%
Bernoulli = BernoulliNB()
Bernoulli.fit(X_train, y_train)
Bernoulli.score(X_test, y_test)
# Out:
# 0.747278750591576

# %%
scores = [Gauss.score(X_test, y_test), Multinomial.score(X_test, y_test), Bernoulli.score(X_test, y_test)]
table = pd.DataFrame({'ML Model': ['Gauss', 'Multi', 'Bernoulli'], 'Accuracy': scores})

table
# Out:
#     ML Model  Accuracy
# 0      Gauss  0.758637
# 1      Multi  0.610033
# 2  Bernoulli  0.747279
